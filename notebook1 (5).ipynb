# %%
# %%HTML
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>dorine</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#     <!-- this is the start of content -->
#     <h2>
#       Bonjour à tous, je m'appelle Dorine
#     </h2>
#
#    <DIV class="avatar">
#   <img src="https://cdn.glitch.me/25da76e6-ddc3-4c52-9a19-6053c457e7b8/logo%20ghibli.jpg?v=1640720872743" style="width:120px" />
#     </DIV>
#     <br>
#
#     <p>
#       L'une de mes passions est le studio Ghibli. Il s'agit d'un studio d'animation japonaise qui produit des longs et courts métrages. Comme par exemple "Spirited Away" ou "Howl's Moving Castle".
#     </p>
#
#     <img src="https://cdn.glitch.me/25da76e6-ddc3-4c52-9a19-6053c457e7b8/spirited%20away.jpg?v=1640720881050" style="width:250px"/>
#
#     <img src="https://cdn.glitch.me/25da76e6-ddc3-4c52-9a19-6053c457e7b8/howl's%20moving%20castle.jpg?v=1640720888957" style="width:250px"/>
#
#    <iframe width="560" height="315" src="https://www.youtube.com/embed/xZpjhzcGa5U?start=13" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
#    <p>
#     Voici la page web de mon camarade Roustan:
#
#     <a href="https://pinto-busy-odometer.glitch.me"
#       target=_blank>ici</a>
#     </p>
#
#   </body>
# </html>
